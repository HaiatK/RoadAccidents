# %%
pip install kagglehub

# %%
import kagglehub
import pandas as pd
import os

# %%
path = kagglehub.dataset_download("fatimahalbaik1/injured-and-dead-in-accidents")
# Out:
# ...
# 100%|██████████| 22.1k/22.1k [00:00<00:00, 29.5MB/s]
# Extracting files...

# %%
print("Files in dataset folder:", os.listdir(path))
# Out:
# Files in dataset folder: ['Injured and Dead in Accidents.csv']

# %%
df = pd.read_csv(path + "/Injured and Dead in Accidents.csv")

# %%
print("\nFirst 5 rows:")
print(df.head())
# Out:
# First 5 rows:
#    ID  hijri_year gregorian_date  gregorian_year  gregorian_month  \
# 0   1        1437     10/14/2015            2015               10
# 1   2        1437     11/13/2015            2015               11
# 2   3        1437     12/12/2015            2015               12
# 3   4        1437      1/11/2016            2016                1
# 4   5        1437      2/10/2016            2016                2
#
#    gregorian_day  region_number region_name  male_count  female_count  ...  \
# 0             14              1      riyadh         279            31  ...
# 1             13              1      riyadh         245            93  ...
# 2             12              1      riyadh         244            89  ...
# 3             11              1      riyadh         303            36  ...
# 4             10              1      riyadh         294            29  ...
#
#    age_18_to_30  age_30_to_40  age_40_to_50  age_over_50  \
# ...

# %%
print("\nDataset shape:")
print(df.shape)
# Out:
# Dataset shape:
# (1152, 21)

# %%
print("\nDataset information:")
df.info()
# Out:
# Dataset information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1152 entries, 0 to 1151
# Data columns (total 21 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   ID                        1152 non-null   int64
#  1   hijri_year                1152 non-null   int64
#  2   gregorian_date            1152 non-null   object
#  3   gregorian_year            1152 non-null   int64
#  4   gregorian_month           1152 non-null   int64
#  5   gregorian_day             1152 non-null   int64
#  6   region_number             1152 non-null   int64
#  7   region_name               1152 non-null   object
#  8   male_count                1152 non-null   int64
#  9   female_count              1152 non-null   int64
#  10  age_under_18              1152 non-null   int64
#  11  age_18_to_30              1152 non-null   int64
#  12  age_30_to_40              1152 non-null   int64
# ...

# %%
print("\nStatistical summary:")
print(df.describe())
# Out:
# Statistical summary:
#                 ID   hijri_year  gregorian_year  gregorian_month  \
# count  1152.000000  1152.000000     1152.000000      1152.000000
# mean    576.500000  1438.000000     2016.694444         6.555556
# std     332.698061     0.816851        0.907754         3.509011
# min       1.000000  1437.000000     2015.000000         1.000000
# 25%     288.750000  1437.000000     2016.000000         3.750000
# 50%     576.500000  1438.000000     2017.000000         6.500000
# 75%     864.250000  1439.000000     2017.000000        10.000000
# max    1152.000000  1439.000000     2018.000000        12.000000
#
#        gregorian_day  region_number   male_count  female_count  age_under_18  \
# count    1152.000000    1152.000000  1152.000000    1152.00000   1152.000000
# mean       16.277778       8.500000    90.861111      16.84809     15.032986
# std         8.536685       4.611774    95.267796      24.20425     17.808781
# ...
